# %% [markdown]
# # Run Configured M3Resp Workflow
#
# This notebook runs the M3Resp workflow selected by `examples/config.yaml`: EIT-only, EMG-only, or combined EIT+EMG.
#
# The YAML `modules` flags control which workflow is selected. When both EIT and EMG are enabled, the configured workflow also performs EMG postprocessing and temporal alignment.
#
# It mirrors the production script `examples/workflow.py` step-by-step so every cell can be executed independently or re-run in sequence.

# %% [markdown]
# ## Setup
#
# Bootstrap the local source checkout, then use the workflow toolbox for package and sibling-repository paths.

# %%
from __future__ import annotations

import os
import sys
from pathlib import Path


def _find_repo_root(start: Path | None = None) -> Path:
    """Find the local m3resp repository root before m3resp is importable."""
    start = (start or Path.cwd()).resolve()
    for candidate in [start, *start.parents]:
        if (
            Path(os.path.join(str(candidate), "pyproject.toml")).exists()
            and Path(os.path.join(str(candidate), "src", "m3resp")).exists()
        ):
            return candidate
    raise RuntimeError(
        "Could not find the m3resp repository root. "
        "Start Jupyter from the repo or notebooks folder."
    )


_repo_root = _find_repo_root()
_src_path = Path(os.path.join(str(_repo_root), "src"))
if _src_path.exists() and str(_src_path) not in sys.path:
    sys.path.insert(0, str(_src_path))

from m3resp.workflows.toolbox import (  # noqa: E402
    configure_workflow_logging,
    configure_workflow_paths,
    log_workflow_summary,
)

REPO_ROOT = configure_workflow_paths("eitprocessing")
REPO_ROOT
# Out:
# PosixPath('/home/mahyart/Desktop/github_repos/m3resp-org/m3resp')

# %%
from m3resp import load_workflow_config
from m3resp.workflows import run_workflow

# %% [markdown]
# ## Configuration
#
# The notebook uses the same YAML file as the runnable example scripts.

# %%
CONFIG_PATH = REPO_ROOT / "examples" / "config.yaml"
cfg = load_workflow_config(CONFIG_PATH)
cfg
# Out:
# WorkflowConfig(modules=ModuleFlags(eit=True, emg=True, vent=True), eit=EITWorkflowConfig(file=PosixPath('/home/mahyart/Desktop/github_repos/m3resp-org/m3resp/data/source/synthetic_demo/20260609_171101/m3resp_demo_multimodal_eit_draeger.bin'), vendor='draeger', processing=EITProcessingConfig(preprocess=SwitchConfig(enabled=True), filter=EITFilterConfig(enabled=True, mode='mdn', lowpass_hz=1.0, highpass_hz=0.05, order=4), breath_detection=SwitchConfig(enabled=True), outputs=EITOutputsConfig(rates=True, breath_intervals=True, continuous_tiv=True, eeli=True, pixel_tiv=True, filtered_data=True, global_impedance=True), subject_type='adult', welch_window_seconds=30.0, breath_min_duration_seconds=0.6666666667)), emg=EMGWorkflowConfig(file=PosixPath('/home/mahyart/Desktop/github_repos/m3resp-org/m3resp/data/source/synthetic_demo/20260610_100034/m3resp_demo_emg.Poly5'), processing=EMGProcessingConfig(preprocess=EMGPreprocessConfig(enabled=True, channel=0, high_pass_hz=80, low_pass_hz=None, envelope_window_seconds=0.5), breath_detection=EMGDetectionConfig(enabled=True, min_breath_width_seconds=1.0, half_window_seconds=0.5), postprocessing=EMGPostprocessingConfig(enabled=True, functions=EMGPostprocessingGroupsConfig(baseline={'moving_baseline': True, 'slopesum_baseline': True}, event_detection={'find_occluded_breaths': True, 'onoffpeak_baseline_crossing': False, 'onoffpeak_slope_extrapolation': False, 'detect_ventilator_breath': True, 'detect_emg_breaths': True}, features={'time_to_peak': False, 'pseudo_slope': False, 'amplitude': False, 'time_product': False, 'area_under_baseline': False, 'respiratory_rate': False}, quality_assessment={'snr_pseudo': False, 'pocc_quality': False, 'interpeak_dist': False, 'percentage_under_baseline': False, 'detect_local_high_aub': False, 'detect_extreme_time_products': False, 'detect_non_consecutive_manoeuvres': True, 'evaluate_bell_curve_error': False, 'evaluate_event_timing': False, 'evaluate_respiratory_rates': False}), ventilator_pressure_channel=0, ventilator_flow_channel=1, ventilator_volume_channel=2, ventilator_fs=None, ventilator_breath_width_seconds=0.5, peep=None, baseline_window_seconds=30.0, baseline_step_seconds=1.0, baseline_percentile=33.0, slope_window_seconds=0.5, aub_window_seconds=5.0))), vent=VentWorkflowConfig(file=PosixPath('/home/mahyart/Desktop/github_repos/m3resp-org/m3resp/data/source/synthetic_demo/20260610_100034/m3resp_demo_ventilator.Poly5')), alignment=AlignmentConfig(method='manual_offset', manual_offset_seconds=0.0), output=OutputConfig(combined=PosixPath('/home/mahyart/Desktop/github_repos/m3resp-org/m3resp/output/multimodal-summary'), eit_only=PosixPath('/home/mahyart/Desktop/github_repos/m3resp-org/m3resp/output/eit-summary'), emg_only=PosixPath('/home/mahyart/Desktop/github_repos/m3resp-org/m3resp/output/emg-summary')), results=ResultsConfig(summary_json=True, parameters_csv=True, event_csvs=True, postprocessing=True, figures=True))

# %% [markdown]
# ## Run Workflow
#
# Run the package-level configured workflow. The returned result contains the populated session, summary values, export directory, and saved figure paths.

# %%
result = run_workflow(config=cfg)
session = result.session

# %% [markdown]
# ## Processing Summary
#
# Log the same compact summary as `examples/workflow.py`.

# %%
configure_workflow_logging()
log_workflow_summary(
    "Configured workflow complete.",
    result.output_dir,
    result.summary,
    active_modules={
        "eit": cfg.modules.eit,
        "emg": cfg.modules.emg,
        "vent": cfg.modules.vent,
    },
)
# Out:
# 10:17:55 | SUCCESS  | Configured workflow complete.
# 10:17:55 | INFO     | Output directory: /home/mahyart/Desktop/github_repos/m3resp-org/m3resp/output/multimodal-summary
# 10:17:55 | INFO     | Active modules: eit=on, emg=on, vent=on
# 10:17:55 | INFO     | filter_mode: mdn
# 10:17:55 | INFO     | respiratory_rate_bpm: 13.883680649101734
# 10:17:55 | INFO     | heart_rate_bpm: 95.60283133387566
# 10:17:55 | INFO     | n_eit_breaths: 13
# 10:17:55 | INFO     | n_continuous_tiv_values: 13
# 10:17:55 | INFO     | n_eeli_values: 13
# 10:17:55 | INFO     | pixel_tiv_shape_per_breath: (32, 32)
# 10:17:55 | INFO     | n_emg_breaths: 0
# 10:17:55 | INFO     | n_ventilator_breaths: 13
# 10:17:55 | INFO     | EMG postprocessing available: baseline (2), event detection (5), features (6), quality assessment (10)
# 10:17:55 | INFO     | EMG postprocessing computed:
# 10:17:55 | INFO     |   baseline: moving_baseline, slopesum_baseline
# 10:17:55 | INFO     |   event detection: detect_ventilator_breath, find_occluded_breaths
# 10:17:55 | INFO     |   quality assessment: detect_non_consecutive_manoeuvres
# 10:17:55 | INFO     | EMG postprocessing skipped:
# 10:17:55 | INFO     |   quality assessment.ventilator respiratory rate: Needs at least two ventilator breaths.

# %% [markdown]
# ## Visualize Output
#
# Configured workflows save available figures into the configured output directory.

# %%
from IPython.display import Image, display

for figure_path in result.figures.values():
    print(figure_path)
    display(Image(filename=str(figure_path)))
# Out:
# /home/mahyart/Desktop/github_repos/m3resp-org/m3resp/output/multimodal-summary/overview.png
# /home/mahyart/Desktop/github_repos/m3resp-org/m3resp/output/multimodal-summary/eit-processing.png
# /home/mahyart/Desktop/github_repos/m3resp-org/m3resp/output/multimodal-summary/eit-rate-detection.png
